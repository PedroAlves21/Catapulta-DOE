# %%
from pathlib import Path
import pandas as pd

csv_in = Path.cwd().parent / "data" / "catapulta_doe.csv"
csv_out = Path.cwd().parent / "data" / "catapulta_doe_ordenado.csv"

df = pd.read_csv(csv_in)
df_ordenado = df.sort_values(["replica"]).reset_index(drop=True)
df_ordenado.to_csv(csv_out, index=False)
print(df_ordenado.head(15))
# Out:
#     ensaio  replica  release_angle  firing_angle  cup_elevation  \
# 0       13        1            176            90            211
# 1       16        1            176           140            211
# 2       14        1            156            90            290
# 3       15        1            176           140            290
# 4       10        1            156           140            211
# 5       12        1            176           140            290
# 6        9        1            156            90            211
# 7       17        1            156           140            290
# 8       26        1            156           140            211
# 9       23        1            156           140            290
# 10      31        1            176           140            290
# 11      28        1            156           140            211
# 12      18        1            176            90            290
# 13      43        1            176           140            211
# ...
