# %% [markdown]
# ## Imports

# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parent

sys.path.append(str(ROOT))

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data_loader import get_csv, load_csv

from src.visualization import (
    plot_correlacao,
    plot_histogramas,
    plot_scatterplots,
    plot_boxplots,
    plot_interacoes,
    plot_replicas,
    plot_top_resultados
)

# %% [markdown]
# ## Carregar dataset

# %%
fontes = get_csv()

fontes
# Out:
# [{'nome': 'catapulta_doe', 'arquivo': 'catapulta_doe.csv'},
#  {'nome': 'catapulta_doe_ordenado', 'arquivo': 'catapulta_doe_ordenado.csv'}]

# %% [markdown]
# ## Ler CSV

# %%
df = load_csv(fontes[0])

df.head()
# Out:
#    ensaio  replica  release_angle  firing_angle  cup_elevation  pin_elevation  \
# 0       1        3            176            90            211            100
# 1       2        3            156           140            290            100
# 2       3        3            156           140            211            100
# 3       4        3            176           140            290            200
# 4       5        2            156            90            211            100
#
#    bungee_elevation  distancia
# 0               100      86.24
# 1               200     129.61
# 2               200      70.52
# 3               100     204.86
# 4               200      69.54

# %% [markdown]
# ## Informações gerais

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ensaio            96 non-null     int64
#  1   replica           96 non-null     int64
#  2   release_angle     96 non-null     int64
#  3   firing_angle      96 non-null     int64
#  4   cup_elevation     96 non-null     int64
#  5   pin_elevation     96 non-null     int64
#  6   bungee_elevation  96 non-null     int64
#  7   distancia         96 non-null     float64
# dtypes: float64(1), int64(7)
# memory usage: 6.1 KB
# None

# %% [markdown]
# ## Estatísticas descritivas

# %%
df.describe()
# Out:
#           ensaio    replica  release_angle  firing_angle  cup_elevation  \
# count  96.000000  96.000000      96.000000     96.000000      96.000000
# mean   48.500000   2.000000     166.000000    115.000000     250.500000
# std    27.856777   0.820783      10.052494     25.131234      39.707351
# min     1.000000   1.000000     156.000000     90.000000     211.000000
# 25%    24.750000   1.000000     156.000000     90.000000     211.000000
# 50%    48.500000   2.000000     166.000000    115.000000     250.500000
# 75%    72.250000   3.000000     176.000000    140.000000     290.000000
# max    96.000000   3.000000     176.000000    140.000000     290.000000
#
#        pin_elevation  bungee_elevation   distancia
# count      96.000000         96.000000   96.000000
# mean      150.000000        150.000000  149.106667
# std        50.262469         50.262469   81.581270
# min       100.000000        100.000000   21.040000
# 25%       100.000000        100.000000   79.570000
# 50%       150.000000        150.000000  145.575000
# 75%       200.000000        200.000000  199.977500
# max       200.000000        200.000000  345.450000

# %% [markdown]
# ## Valores Nulos

# %%
df.isnull().sum()
# Out:
# ensaio              0
# replica             0
# release_angle       0
# firing_angle        0
# cup_elevation       0
# pin_elevation       0
# bungee_elevation    0
# distancia           0
# dtype: int64

# %% [markdown]
# ## Matriz de correlação

# %%
plot_correlacao(df)

# %% [markdown]
# ## Histogramas

# %%
plot_histogramas(df)

# %% [markdown]
# ## Scatterplots

# %%
plot_scatterplots(df, df.columns, 'distancia')

# %% [markdown]
# ## Boxplots

# %%
plot_boxplots(df)

# %% [markdown]
# ## Interações

# %%
plot_interacoes(df)

# %% [markdown]
# ## Réplicas

# %%
plot_replicas(df)

# %% [markdown]
# ## Top resultados

# %%
plot_top_resultados(df)
